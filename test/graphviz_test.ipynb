# %%
import graphviz

# %%
feature_name = "features 1"
threshold = 0.112
criterion_name = "gini"
criterion_value = 0.125
sample = 2
proba_vector = [0.5, 0.5]
majority_class = "pouet"

# %%
d = graphviz.Digraph()
d.node(str(1), f"{feature_name} ≤ {threshold}\n{criterion_name} = {criterion_value}", shape="ellipse")

# %%
d.node(str(2), f"{criterion_name} = {criterion_value}\nsample = {sample}\nProbabilities : {proba_vector}\nMajority Class = {majority_class}", shape="rectangle", style="rounded")

# %%
d

# %%
type(d)
# Out:
# graphviz.graphs.Digraph
